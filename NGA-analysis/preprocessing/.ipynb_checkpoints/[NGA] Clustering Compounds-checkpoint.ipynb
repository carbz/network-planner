# %% [markdown]
# <div><h1 style="width: 500px; margin: 0 auto;">[NGA] Clustering Compounds to Determine Villages</h1><img src="http://modi.mech.columbia.edu/wp-content/uploads/2013/10/sel-logotype.png" style="width:200px; float:right" />
# </div>
#
# - exploring scikit-learn to cluster compounds
# - input: compounds manually identified via visual inspection
# - output: clustered 'villages' cosisting of compounds
#
# Start: Dec 16, 14
#
# Tutorial via: http://scikit-learn.org/stable/auto_examples/cluster/plot_dbscan.html

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
"""
===================================
Demo of DBSCAN clustering algorithm
===================================

Finds core samples of high density and expands clusters from them.

"""
print(__doc__)

import numpy as np

#import sklearn

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler
# Out:
# ===================================
# Demo of DBSCAN clustering algorithm
# ===================================
#
# Finds core samples of high density and expands clusters from them.

# %%
## Psudo Code by Brandon
import itertools 

clusters = dbscan(pts, r, min)
pairs = zip(clusters, pts)
grouped = itertools.groupby(sorted(pairs, key=lambda tup: tup[0]))
for group, data in grouped:
    counts = len(data)
    centroid = np.mean(data, axis=0)
    print counts, centroid
###

# %%
##############################################################################
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
                            random_state=0)

X = StandardScaler().fit_transform(X)

X
# Out:
# array([[ 0.49426097,  1.45106697],
#        [-1.42808099, -0.83706377],
#        [ 0.33855918,  1.03875871],
#        ...,
#        [-0.05713876, -0.90926105],
#        [-1.16939407,  0.03959692],
#        [ 0.26322951, -0.92649949]])

# %%
##Instead, Import manually identified compounds
# %%timeit
import pandas as pd
import numpy as np

#Import Compound Data
compounds_identified_dir = '/Users/carbz/Dropbox/Nigeria-NEAP-GIS/shapefiling/Kano_Voter_Validation/StructureCountNearPollingBooths-20141119.csv'

#reading the csv version as pandas DF
compounds = pd.read_csv(compounds_identified_dir)

##How many compounds belong to each cluster?? 
grouped = compounds.groupby('Cluster')
#compound_summary = grouped[1].agg([np.count_nonzero])
compound_summary = grouped.agg([np.count_nonzero])


#list of unique compound clusters
v= list(compound_summary.index)

#how many compounds have been uniquely identified? 
len(compounds)
# Out:
#                     X             Y    Unnamed: 3
#         count_nonzero count_nonzero count_nonzero
# Cluster
# 1                 118           118           118
# 2                 138           138           138
# 3                  84            84            84
# 4                  46            46            46
# 5                 168           168           168
# 6                  42            42            42
# 7                  83            83            83
# 8                  53            53            53
# 9                  77            77            77
# 10                 22            22            22
# 11                 40            40            40
# 12                 44            44            44
# 13                 40            40            40
# 14                 13            13            13
# 15                 67            67            67
# 16                 40            40            40
# 17                 93            93            93
# 19                 17            17            17
# 20                 17            17            17
# 38                  2             2             2
# 41                 31            31            31
# 42                 76            76            76
# 43                 22            22            22
# 44                 41            41            41
# 45                 82            82            82
# 46                 35            35            35
# 47                 43            43            43
# 48                 24            24            24
# 49                 87            87            87
# 50                 17            17            17
# 51                 78            78            78

# %%
v = range(1,18) + range(19,21) + range(38,39) + range(41,52)

i=v[4]
# i=2
i=5
cluster = compounds[compounds['Cluster'] == i][['X', 'Y']].values
X = cluster
X
# Out:
# array([[  9.17587105,  11.59193431],
#        [  9.17760269,  11.59227058],
#        [  9.17724415,  11.59215102],
#        [  9.1766644 ,  11.59205387],
#        [  9.17581003,  11.59353347],
#        [  9.17633638,  11.59400425],
#        [  9.17648895,  11.59506537],
#        [  9.17680934,  11.595439  ],
#        [  9.17831212,  11.59454228],
#        [  9.17853334,  11.59379501],
#        [  9.17810616,  11.59329434],
#        [  9.17857148,  11.59261433],
#        [  9.17931906,  11.59297302],
#        [  9.18382331,  11.59627551],
#        [  9.17713404,  11.59578972],
#        [  9.17613549,  11.59628291],
#        [  9.17657183,  11.595987  ],
#        [  9.17580824,  11.59555134],
#        [  9.1735678 ,  11.59622538],
#        [  9.17378597,  11.5969816 ],
#        [  9.17424748,  11.59689941],
#        [  9.1786025 ,  11.59754055],
#        [  9.1810695 ,  11.59759809],
#        [  9.1825883 ,  11.59650485],
#        [  9.18271417,  11.59558422],
#        [  9.18255474,  11.59612674],
#        [  9.18181706,  11.60028999],
#        [  9.18289511,  11.59998738],
#        [  9.18294555,  11.60127191],
#        [  9.17360985,  11.59913797],
#        [  9.1743979 ,  11.59871803],
#        [  9.17662336,  11.59822397],
#        [  9.17613161,  11.59901446],
#        [  9.17722858,  11.59873655],
#        [  9.17678097,  11.59870568],
#        [  9.17591096,  11.59982347],
#        [  9.175155  ,  11.6020394 ],
#        [  9.17548169,  11.60243239],
#        [  9.17632418,  11.60199448],
#        [  9.17771689,  11.60233695],
#        [  9.17629553,  11.60249414],
#        [  9.17420015,  11.60415266],
#        [  9.17441153,  11.60349696],
#        [  9.1737304 ,  11.60193629],
#        [  9.17398485,  11.60168705],
#        [  9.17406314,  11.60129976],
#        [  9.17434499,  11.60083961],
#        [  9.17337809,  11.60019156],
#        [  9.16791578,  11.6025161 ],
#        [  9.1698976 ,  11.60168635],
#        [  9.16762072,  11.60113514],
#        [  9.17230474,  11.60064006],
#        [  9.16994971,  11.60116576],
#        [  9.16966835,  11.60105858],
#        [  9.16912649,  11.60097692],
#        [  9.16912128,  11.6005482 ],
#        [  9.16972045,  11.60066558],
#        [  9.16700984,  11.59909787],
#        [  9.16736998,  11.59996833],
#        [  9.16825466,  11.60007186],
#        [  9.16817637,  11.59944682],
#        [  9.1697187 ,  11.59940081],
#        [  9.16918632,  11.5996884 ],
#        [  9.16854825,  11.59956953],
#        [  9.16831729,  11.59975359],
#        [  9.16785146,  11.598979  ],
#        [  9.16798847,  11.59848434],
#        [  9.16848171,  11.59895983],
#        [  9.1659075 ,  11.59688579],
#        [  9.16689005,  11.59705835],
#        [  9.16693311,  11.59749933],
#        [  9.16787651,  11.59693564],
#        [  9.16732064,  11.59757986],
#        [  9.16808007,  11.59822791],
#        [  9.16870248,  11.59811287],
#        [  9.16957151,  11.59790964],
#        [  9.1700804 ,  11.59747249],
#        [  9.16962631,  11.59696248],
#        [  9.16862419,  11.5964333 ],
#        [  9.16853024,  11.59675925],
#        [  9.16879449,  11.59606355],
#        [  9.16768838,  11.59620553],
#        [  9.16587283,  11.59577959],
#        [  9.16474384,  11.59410571],
#        [  9.16486589,  11.59370219],
#        [  9.16742901,  11.58921854],
#        [  9.167963  ,  11.58851609],
#        [  9.16657464,  11.58858334],
#        [  9.1659186 ,  11.58885237],
#        [  9.16656461,  11.5921509 ],
#        [  9.1690921 ,  11.59048343],
#        [  9.16831838,  11.59092696],
#        [  9.16827253,  11.59133681],
#        [  9.16704603,  11.59045535],
#        [  9.16765928,  11.59116277],
#        [  9.16759051,  11.59041605],
#        [  9.16670789,  11.59000059],
#        [  9.16608318,  11.59120207],
#        [  9.16557883,  11.59359941],
#        [  9.16726382,  11.59320079],
#        [  9.16688556,  11.59368362],
#        [  9.17107512,  11.59447524],
#        [  9.17018104,  11.59428436],
#        [  9.16933281,  11.59396995],
#        [  9.17007215,  11.59352081],
#        [  9.17026128,  11.59211721],
#        [  9.16800889,  11.59267865],
#        [  9.16751027,  11.59184211],
#        [  9.16582527,  11.59266181],
#        [  9.16705784,  11.58756901],
#        [  9.18187442,  11.58658179],
#        [  9.18198638,  11.58596171],
#        [  9.18147827,  11.58597015],
#        [  9.18221029,  11.58509697],
#        [  9.18299829,  11.58474263],
#        [  9.18320498,  11.58531632],
#        [  9.18251989,  11.58589717],
#        [  9.18093144,  11.58556017],
#        [  9.18038437,  11.585601  ],
#        [  9.18026453,  11.58599402],
#        [  9.17941526,  11.58462101],
#        [  9.17932668,  11.58565204],
#        [  9.17906617,  11.58643297],
#        [  9.17772192,  11.58617266],
#        [  9.17803975,  11.58500382],
#        [  9.16938343,  11.5837223 ],
#        [  9.1697388 ,  11.58454785],
#        [  9.16826657,  11.58410026],
#        [  9.17709294,  11.58507176],
#        [  9.17608996,  11.58420712],
#        [  9.17592376,  11.58465067],
#        [  9.17522454,  11.58475173],
#        [  9.17504114,  11.58557707],
#        [  9.17623325,  11.58519528],
#        [  9.17653127,  11.58619466],
#        [  9.17574036,  11.58581288],
#        [  9.17551684,  11.58631257],
#        [  9.17549391,  11.58675611],
#        [  9.17500675,  11.58681787],
#        [  9.17484628,  11.58602623],
#        [  9.1742101 ,  11.58593078],
#        [  9.17345358,  11.58420712],
#        [  9.17278875,  11.58409483],
#        [  9.17151067,  11.58405553],
#        [  9.17204941,  11.58486964],
#        [  9.17144763,  11.58561075],
#        [  9.17179724,  11.58597008],
#        [  9.17406261,  11.58765698],
#        [  9.17363617,  11.58729891],
#        [  9.17317927,  11.58778628],
#        [  9.17979923,  11.58743816],
#        [  9.1813933 ,  11.5870602 ],
#        [  9.1840027 ,  11.58712982],
#        [  9.1823071 ,  11.58748789],
#        [  9.18322089,  11.58827365],
#        [  9.18295691,  11.58845269],
#        [  9.17627827,  11.59051834],
#        [  9.17683936,  11.58988223],
#        [  9.17677632,  11.58936345],
#        [  9.17739415,  11.58899908],
#        [  9.17850373,  11.58938816],
#        [  9.1787496 ,  11.5905554 ],
#        [  9.1797583 ,  11.59040718],
#        [  9.17794263,  11.5916547 ],
#        [  9.17721763,  11.59135826],
#        [  9.16942996,  11.58711692],
#        [  9.1831667 ,  11.5869512 ],
#        [  9.18391079,  11.58661987]])

# %%
##############################################################################
# Compute DBSCAN
db = DBSCAN(eps=0.002, min_samples=4).fit(X)

core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

print('Estimated number of clusters: %d' % n_clusters_)

##############################################################################
# Plot result
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 5

# %%
db
n_clusters_
# Out:
# 5

# %%
import itertools

def haversine_cluster(pts, eps, min_s):
    mat = dist_mat(pts)
    scan = DBSCAN(eps, min_samples=min_s, metric='precomputed').fit(mat)
    return sorted(zip(scan.labels_, pts), key=lambda tup: tup[0])
fig =plt.figure(figsize = (12, 8))
ax = fig.add_subplot(111)

clusters = itertools.groupby(haversine_cluster(X, 220, 4), key=lambda tup: tup[0])
c = itertools.cycle('rgbmy')


for group, data in clusters:
    data = zip(*data)[1]
    pts = np.row_stack(data)
    clr = c.next()
    if group == -1:
        clr = 'k'
    print group, clr
    ax.scatter(pts[:, 0], pts[:, 1], c=clr, s=80)
# Out:
# -1 k
# 0 g
# 1 b
# 2 m
# 3 y
# 4 r

# %%
compounds = haversine_cluster(X, 250, 4)

##How many compounds belong to each cluster?? 
grouped = compounds.groupby('Cluster')
#compound_summary = grouped[1].agg([np.count_nonzero])
compound_summary = grouped.agg([np.count_nonzero])

# %%
compounds
# Out:
# [(-1, array([  9.18181706,  11.60028999])),
#  (-1, array([  9.18289511,  11.59998738])),
#  (-1, array([  9.18294555,  11.60127191])),
#  (0, array([  9.16791578,  11.6025161 ])),
#  (0, array([  9.1698976 ,  11.60168635])),
#  (0, array([  9.16762072,  11.60113514])),
#  (0, array([  9.16994971,  11.60116576])),
#  (0, array([  9.16966835,  11.60105858])),
#  (0, array([  9.16912649,  11.60097692])),
#  (0, array([  9.16912128,  11.6005482 ])),
#  (0, array([  9.16972045,  11.60066558])),
#  (0, array([  9.16700984,  11.59909787])),
#  (0, array([  9.16736998,  11.59996833])),
#  (0, array([  9.16825466,  11.60007186])),
#  (0, array([  9.16817637,  11.59944682])),
#  (0, array([  9.1697187 ,  11.59940081])),
#  (0, array([  9.16918632,  11.5996884 ])),
#  (0, array([  9.16854825,  11.59956953])),
#  (0, array([  9.16831729,  11.59975359])),
#  (0, array([  9.16785146,  11.598979  ])),
#  (0, array([  9.16798847,  11.59848434])),
#  (0, array([  9.16848171,  11.59895983])),
#  (0, array([  9.1659075 ,  11.59688579])),
#  (0, array([  9.16689005,  11.59705835])),
#  (0, array([  9.16693311,  11.59749933])),
#  (0, array([  9.16787651,  11.59693564])),
#  (0, array([  9.16732064,  11.59757986])),
#  (0, array([  9.16808007,  11.59822791])),
#  (0, array([  9.16870248,  11.59811287])),
#  (0, array([  9.16957151,  11.59790964])),
#  (0, array([  9.1700804 ,  11.59747249])),
#  (0, array([  9.16962631,  11.59696248])),
#  (0, array([  9.16862419,  11.5964333 ])),
#  (0, array([  9.16853024,  11.59675925])),
#  (0, array([  9.16879449,  11.59606355])),
#  (0, array([  9.16768838,  11.59620553])),
#  (0, array([  9.16587283,  11.59577959])),
#  (0, array([  9.16474384,  11.59410571])),
#  (0, array([  9.16486589,  11.59370219])),
#  (0, array([  9.16742901,  11.58921854])),
#  (0, array([  9.167963  ,  11.58851609])),
#  (0, array([  9.16657464,  11.58858334])),
#  (0, array([  9.1659186 ,  11.58885237])),
#  (0, array([  9.16656461,  11.5921509 ])),
#  (0, array([  9.1690921 ,  11.59048343])),
#  (0, array([  9.16831838,  11.59092696])),
#  (0, array([  9.16827253,  11.59133681])),
#  (0, array([  9.16704603,  11.59045535])),
#  (0, array([  9.16765928,  11.59116277])),
#  (0, array([  9.16759051,  11.59041605])),
#  (0, array([  9.16670789,  11.59000059])),
#  (0, array([  9.16608318,  11.59120207])),
#  (0, array([  9.16557883,  11.59359941])),
#  (0, array([  9.16726382,  11.59320079])),
#  (0, array([  9.16688556,  11.59368362])),
#  (0, array([  9.17107512,  11.59447524])),
#  (0, array([  9.17018104,  11.59428436])),
#  (0, array([  9.16933281,  11.59396995])),
#  (0, array([  9.17007215,  11.59352081])),
#  (0, array([  9.17026128,  11.59211721])),
#  (0, array([  9.16800889,  11.59267865])),
#  (0, array([  9.16751027,  11.59184211])),
#  (0, array([  9.16582527,  11.59266181])),
#  (0, array([  9.16705784,  11.58756901])),
#  (0, array([  9.16942996,  11.58711692])),
#  (1, array([  9.18187442,  11.58658179])),
#  (1, array([  9.18198638,  11.58596171])),
#  (1, array([  9.18147827,  11.58597015])),
#  (1, array([  9.18221029,  11.58509697])),
#  (1, array([  9.18299829,  11.58474263])),
#  (1, array([  9.18320498,  11.58531632])),
#  (1, array([  9.18251989,  11.58589717])),
#  (1, array([  9.18093144,  11.58556017])),
#  (1, array([  9.18038437,  11.585601  ])),
#  (1, array([  9.18026453,  11.58599402])),
#  (1, array([  9.17941526,  11.58462101])),
#  (1, array([  9.17932668,  11.58565204])),
#  (1, array([  9.17906617,  11.58643297])),
#  (1, array([  9.17772192,  11.58617266])),
#  (1, array([  9.17803975,  11.58500382])),
#  (1, array([  9.16938343,  11.5837223 ])),
#  (1, array([  9.1697388 ,  11.58454785])),
#  (1, array([  9.16826657,  11.58410026])),
#  (1, array([  9.17709294,  11.58507176])),
#  (1, array([  9.17608996,  11.58420712])),
#  (1, array([  9.17592376,  11.58465067])),
#  (1, array([  9.17522454,  11.58475173])),
#  (1, array([  9.17504114,  11.58557707])),
#  (1, array([  9.17623325,  11.58519528])),
#  (1, array([  9.17653127,  11.58619466])),
#  (1, array([  9.17574036,  11.58581288])),
#  (1, array([  9.17551684,  11.58631257])),
#  (1, array([  9.17549391,  11.58675611])),
#  (1, array([  9.17500675,  11.58681787])),
#  (1, array([  9.17484628,  11.58602623])),
#  (1, array([  9.1742101 ,  11.58593078])),
#  (1, array([  9.17345358,  11.58420712])),
#  (1, array([  9.17278875,  11.58409483])),
#  (1, array([  9.17151067,  11.58405553])),
#  (1, array([  9.17204941,  11.58486964])),
#  (1, array([  9.17144763,  11.58561075])),
#  (1, array([  9.17179724,  11.58597008])),
#  (1, array([  9.17406261,  11.58765698])),
#  (1, array([  9.17363617,  11.58729891])),
#  (1, array([  9.17317927,  11.58778628])),
#  (1, array([  9.17979923,  11.58743816])),
#  (1, array([  9.1813933,  11.5870602])),
#  (1, array([  9.1840027 ,  11.58712982])),
#  (1, array([  9.1823071 ,  11.58748789])),
#  (1, array([  9.18322089,  11.58827365])),
#  (1, array([  9.18295691,  11.58845269])),
#  (1, array([  9.1831667,  11.5869512])),
#  (1, array([  9.18391079,  11.58661987])),
#  (2, array([  9.17587105,  11.59193431])),
#  (2, array([  9.17760269,  11.59227058])),
#  (2, array([  9.17724415,  11.59215102])),
#  (2, array([  9.1766644 ,  11.59205387])),
#  (2, array([  9.17581003,  11.59353347])),
#  (2, array([  9.17633638,  11.59400425])),
#  (2, array([  9.17648895,  11.59506537])),
#  (2, array([  9.17680934,  11.595439  ])),
#  (2, array([  9.17831212,  11.59454228])),
#  (2, array([  9.17853334,  11.59379501])),
#  (2, array([  9.17810616,  11.59329434])),
#  (2, array([  9.17857148,  11.59261433])),
#  (2, array([  9.17931906,  11.59297302])),
#  (2, array([  9.17713404,  11.59578972])),
#  (2, array([  9.17613549,  11.59628291])),
#  (2, array([  9.17657183,  11.595987  ])),
#  (2, array([  9.17580824,  11.59555134])),
#  (2, array([  9.1735678 ,  11.59622538])),
#  (2, array([  9.17378597,  11.5969816 ])),
#  (2, array([  9.17424748,  11.59689941])),
#  (2, array([  9.1786025 ,  11.59754055])),
#  (2, array([  9.17360985,  11.59913797])),
#  (2, array([  9.1743979 ,  11.59871803])),
#  (2, array([  9.17662336,  11.59822397])),
#  (2, array([  9.17613161,  11.59901446])),
#  (2, array([  9.17722858,  11.59873655])),
#  (2, array([  9.17678097,  11.59870568])),
#  (2, array([  9.17591096,  11.59982347])),
#  (2, array([  9.175155 ,  11.6020394])),
#  (2, array([  9.17548169,  11.60243239])),
#  (2, array([  9.17632418,  11.60199448])),
#  (2, array([  9.17771689,  11.60233695])),
#  (2, array([  9.17629553,  11.60249414])),
#  (2, array([  9.17420015,  11.60415266])),
#  (2, array([  9.17441153,  11.60349696])),
#  (2, array([  9.1737304 ,  11.60193629])),
#  (2, array([  9.17398485,  11.60168705])),
#  (2, array([  9.17406314,  11.60129976])),
#  (2, array([  9.17434499,  11.60083961])),
#  (2, array([  9.17337809,  11.60019156])),
#  (2, array([  9.17230474,  11.60064006])),
#  (2, array([  9.17627827,  11.59051834])),
#  (2, array([  9.17683936,  11.58988223])),
#  (2, array([  9.17677632,  11.58936345])),
#  (2, array([  9.17739415,  11.58899908])),
#  (2, array([  9.17850373,  11.58938816])),
#  (2, array([  9.1787496,  11.5905554])),
#  (2, array([  9.1797583 ,  11.59040718])),
#  (2, array([  9.17794263,  11.5916547 ])),
#  (2, array([  9.17721763,  11.59135826])),
#  (3, array([  9.18382331,  11.59627551])),
#  (3, array([  9.1810695 ,  11.59759809])),
#  (3, array([  9.1825883 ,  11.59650485])),
#  (3, array([  9.18271417,  11.59558422])),
#  (3, array([  9.18255474,  11.59612674]))]

# %%
# Function for the MST & distance matrix
#build a distance martrix (edge weights)

__author__ = 'Brandon Ogle'
import numpy as np
from numpy import sin, cos, pi, arcsin, sqrt

def hav_dist(vector,point):
    lat = vector[:, 0]
    lon = vector[:, 1]
    x, y = point
    return get_hav_distance(lat, lon, x, y)

def get_hav_distance(lat, lon, pcode_lat, pcode_lon):
    """
    Find the distance between a vector of (lat,lon) and the reference point (pcode_lat,pcode_lon).
    """
    rad_factor = pi / 180.0  # degrees to radians for trig functions
    lat_in_rad = lat * rad_factor
    lon_in_rad = lon * rad_factor
    pcode_lat_in_rad = pcode_lat * rad_factor
    pcode_lon_in_rad = pcode_lon * rad_factor
    delta_lon = lon_in_rad - pcode_lon_in_rad
    delta_lat = lat_in_rad - pcode_lat_in_rad
    # Next two lines is the Haversine formula
    inverse_angle = (np.sin(delta_lat / 2) ** 2 + np.cos(pcode_lat_in_rad) *
                     np.cos(lat_in_rad) * np.sin(delta_lon / 2) ** 2)
    haversine_angle = 2 * np.arcsin(np.sqrt(inverse_angle))
    earth_radius =  6371010 # meters
    return haversine_angle * earth_radius


# """Returns the computed distance matrix"""
def dist_mat(coords):
    """
    returns the distance matrix of a numpy array (haversine)
    """
    return np.row_stack(map(lambda pt: hav_dist(coords, pt), coords))
