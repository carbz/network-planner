# %% [markdown]
# <div><h1 style="width: 6000px; margin: 0 auto;">[MMR] Mandalay Approximate Low Voltage Network</h1><img src="http://modi.mech.columbia.edu/wp-content/uploads/2013/10/sel-logotype.png" style="width:200px; float:right" />
# </div>
#
# - households in Mandalay manually identified from on ground surveys
#
# Start: July, 2015

# %%
# %prun [x for x in range(50)]
# %timeit

# %% [markdown]
# ## 0. Load Libraries and nx Functions

# %%
import networkx as nx
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
# Function for the MST & distance matrix
#build a distance martrix (edge weights)

__author__ = 'Brandon Ogle'
import numpy as np
from numpy import sin, cos, pi, arcsin, sqrt

def hav_dist(vector,point):
    lat = vector[:, 0]
    lon = vector[:, 1]
    x, y = point
    return get_hav_distance(lat, lon, x, y)

def get_hav_distance(lat, lon, pcode_lat, pcode_lon):
    """
    Find the distance between a vector of (lat,lon) and the reference point (pcode_lat,pcode_lon).
    """
    rad_factor = pi / 180.0  # degrees to radians for trig functions
    lat_in_rad = lat * rad_factor
    lon_in_rad = lon * rad_factor
    pcode_lat_in_rad = pcode_lat * rad_factor
    pcode_lon_in_rad = pcode_lon * rad_factor
    delta_lon = lon_in_rad - pcode_lon_in_rad
    delta_lat = lat_in_rad - pcode_lat_in_rad
    # Next two lines is the Haversine formula
    inverse_angle = (np.sin(delta_lat / 2) ** 2 + np.cos(pcode_lat_in_rad) *
                     np.cos(lat_in_rad) * np.sin(delta_lon / 2) ** 2)
    haversine_angle = 2 * np.arcsin(np.sqrt(inverse_angle))
    earth_radius =  6371010 # meters
    return haversine_angle * earth_radius


# """Returns the computed distance matrix"""
def dist_mat(coords):
    """
    returns the distance matrix of a numpy array (haversine)
    """
    return np.row_stack(map(lambda pt: hav_dist(coords, pt), coords))
    
def connected_graph_mst(coords, plot=True):
    dmat = dist_mat(coords)
    G = nx.from_numpy_matrix(dmat)
    nx.set_node_attributes(G, 'coords', {i:coord for i, coord in enumerate(coords)})
    mst = nx.algorithms.minimum_spanning_tree(G)
    
    if plot:
        import matplotlib.pyplot as plt
        fig = plt.figure(figsize=(10,10))
        ax = fig.add_subplot(111)
        nx.draw(mst, nx.get_node_attributes(mst, 'coords'), node_size=40, ax=ax)
    return mst

# %% [markdown]
# ## 1. Import the Manually Identified compounds

# %%
# %%timeit
import pandas as pd
import numpy as np

#Import Compound Data
hhs_identified_dir = '/Users/carbz/Dropbox/Myanmar-ADB/10-draft_report/VillageSurveyAnalyses/AllFormhubSurveys-Composite-withMetaData.csv'


#reading the csv version as pandas DF
households = pd.read_csv(hhs_identified_dir)

#how many compounds have been uniquely identified? 
len(households)
# households
##How many households belong to each cluster?? 
grouped = compounds.groupby('VILLAGE_1')
#compound_summary = grouped[1].agg([np.count_nonzero])
household_summary = grouped.agg([np.count_nonzero])
print household_summary[[1]]


#list of unique compound clusters
v= list(household_summary.index)
# Out:
#                             End
#                   count_nonzero
# VILLAGE_1
# Kha-Ta Chin                  47
# Lei Gyi                      19
# Let Pan Gyine                 5
# Magyi Kan                    83
# Pann Tin                     84
# 845                         4      ...             7/2/14     17:23:10
# 846                         5      ...             7/2/14     17:25:34
# 847                         6      ...             7/2/14     17:26:56
# 848                         4      ...             7/2/14     17:28:58
# 849                         5      ...             7/2/14     17:30:37
#
#      formhub GMT hour offset  formhub GMT minute offset  Date Visited  \
# 0                          6                          30      6/24/14
# 1                          6                          30      6/24/14
# 2                          6                          30      6/24/14
# 3                          6                          30      6/24/14
# 4                          6                          30      6/24/14
# 5                          6                          30      6/24/14
# 6                          6                          30      6/25/14
# 7                          6                          30      6/25/14
# 8                          6                          30      6/25/14
# 9                          6                          30      6/25/14
# 10                         6                          30      6/25/14
# 11                         6                          30      6/25/14
# 12                         6                          30      6/25/14
# 13                         6                          30      6/25/14
# 14                         6                          30      6/25/14
# 15                         6                          30      6/25/14
# 16                         6                          30      6/25/14
# 17                         6                          30      6/25/14
# 18                         6                          30      6/25/14
# 19                         6                          30      6/25/14
# 20                         6                          30      6/25/14
# 21                         6                          30      6/25/14
# 22                         6                          30      6/25/14
# 23                         6                          30      6/25/14
# 24                         6                          30      6/25/14
# 25                         6                          30      6/25/14
# 26                         6                          30      6/25/14
# 27                         6                          30      6/25/14
# 28                         6                          30      6/25/14
# 29                         6                          30      6/25/14
# ..                       ...                         ...          ...
# 820                        9                           -       7/2/14
# 821                        9                           -       7/2/14
# 822                        9                           -       7/2/14
# 823                        9                           -       7/2/14
# 824                        9                           -       7/2/14
# 825                        9                           -       7/2/14
# 826                        9                           -       7/2/14
# 827                        9                           -       7/2/14
# 828                        9                           -       7/2/14
# 829                        9                           -       7/2/14
# 830                        9                           -       7/2/14
# 831                        9                           -       7/2/14
# 832                        9                           -       7/2/14
# 833                        9                           -       7/2/14
# 834                        9                           -       7/2/14
# 835                        9                           -       7/2/14
# 836                        9                           -       7/2/14
# 837                        9                           -       7/2/14
# 838                        9                           -       7/2/14
# 839                        9                           -       7/2/14
# 840                        9                           -       7/2/14
# 841                        9                           -       7/2/14
# 842                        9                           -       7/2/14
# 843                        9                           -       7/2/14
# 844                        9                           -       7/2/14
# 845                        9                           -       7/2/14
# 846                        9                           -       7/2/14
# 847                        9                           -       7/2/14
# 848                        9                           -       7/2/14
# 849                        9                           -       7/2/14
#
#     Time Visited Village gap from last survey HHs_TOTAL      VILLAGE_1
# 0     6:30:04 PM   False                   56        86   Ta-Mar Gonne
# 1     9:10:06 PM   False                   40       105  Let Pan Gyine
# 2     9:14:09 PM   False                    4       105  Let Pan Gyine
# 3     9:17:59 PM   False                    3       105  Let Pan Gyine
# 4     9:29:32 PM   False                   11       105  Let Pan Gyine
# 5     9:32:10 PM   False                    2       105  Let Pan Gyine
# 6     9:08:54 PM   False                   55       113          Zawin
# 7     9:14:12 PM   False                    5       113          Zawin
# 8     9:15:34 PM   False                    1       113          Zawin
# 9     9:16:59 PM   False                    1       113          Zawin
# 10    9:23:38 PM   False                    6       113          Zawin
# 11    9:24:56 PM   False                    1       113          Zawin
# 12    9:26:46 PM   False                    1       113          Zawin
# 13    9:27:32 PM   False                    -       113          Zawin
# 14    9:28:58 PM   False                    1       113          Zawin
# 15    9:31:22 PM   False                    2       113          Zawin
# 16    9:33:11 PM   False                    1       113          Zawin
# 17    9:34:15 PM   False                    1       113          Zawin
# 18    9:35:44 PM   False                    1       113          Zawin
# 19    9:37:37 PM   False                    1       113          Zawin
# 20    9:41:41 PM   False                    4       113          Zawin
# 21    9:43:00 PM   False                    1       113          Zawin
# 22    9:44:59 PM   False                    1       113          Zawin
# 23    9:46:07 PM   False                    1       113          Zawin
# 24    9:47:11 PM   False                    1       113          Zawin
# 25    9:49:54 PM   False                    2       113          Zawin
# 26    9:50:40 PM   False                    -       113          Zawin
# 27    9:52:16 PM   False                    1       113          Zawin
# 28    9:53:01 PM   False                    -       113          Zawin
# 29    9:54:13 PM   False                    1       113          Zawin
# ..           ...     ...                  ...       ...            ...
# 820  11:07:21 PM   False                    2        90       Pann Tin
# 821  11:10:02 PM   False                    2        90       Pann Tin
# 822  11:11:32 PM   False                    1        90       Pann Tin
# 823  11:13:21 PM   False                    1        90       Pann Tin
# 824  11:15:55 PM   False                    2        90       Pann Tin
# 825  11:17:50 PM   False                    1        90       Pann Tin
# 826  11:21:16 PM   False                    3        90       Pann Tin
# 827  11:23:15 PM   False                    1        90       Pann Tin
# 828  11:24:44 PM   False                    1        90       Pann Tin
# 829  11:26:54 PM   False                    2        90       Pann Tin
# 830  11:28:38 PM   False                    1        90       Pann Tin
# 831  11:32:10 PM   False                    3        90       Pann Tin
# 832  11:34:25 PM   False                    2        90       Pann Tin
# 833  11:36:09 PM   False                    1        90       Pann Tin
# 834  11:39:10 PM   False                    3        90       Pann Tin
# 835  11:40:50 PM   False                    1        90       Pann Tin
# 836  11:44:44 PM   False                    3        90       Pann Tin
# 837  11:46:13 PM   False                    1        90       Pann Tin
# 838   2:07:46 AM   False                   21       194    Kha-Ta Chin
# 839   2:10:30 AM   False                    2       194    Kha-Ta Chin
# 840   2:12:29 AM   False                    1       194    Kha-Ta Chin
# 841   2:14:08 AM   False                    1       194    Kha-Ta Chin
# 842   2:15:44 AM   False                    1       194    Kha-Ta Chin
# 843   2:17:42 AM   False                    1       194    Kha-Ta Chin
# 844   2:19:18 AM   False                    1       194    Kha-Ta Chin
# 845   2:23:10 AM   False                    3       194    Kha-Ta Chin
# 846   2:25:34 AM   False                    2       194    Kha-Ta Chin
# 847   2:26:56 AM   False                    1       194    Kha-Ta Chin
# 848   2:28:58 AM   False                    2       194    Kha-Ta Chin
# 849   2:30:37 AM   False                    1       194    Kha-Ta Chin
#
# [850 rows x 48 columns]

# %%
##Set up the nodal NX thang

#Where's the shp at??
hhs_identified_dir = '/Users/carbz/Dropbox/Myanmar-ADB/10-draft_report/VillageSurveyAnalyses/AllFormhubSurveys-Composite.shp'

#Reading in shape file
nodes = nx.read_shp(hhs_identified_dir)

# convert the node names from coords to integers, cache the coords as attrs
nodes = nx.convert_node_labels_to_integers(nodes, label_attribute='VILLAGE_1')

# create a dataframe with the network nodes with int label index, attrs as cols
node_df = pd.DataFrame(nodes.node).T

# cast coords to tuples (hashable)
node_df['VILLAGE_1'] = node_df['VILLAGE_1'].apply(tuple)

# build a vector of all the coordinates in the metrics dataframe
coords_vec = np.vstack(node_df['VILLAGE_1'].values)

# %% [markdown]
# ## 2. Calculate Geospatial and Dispersion Metrics
# (Using Brandon's Function to Calculate MST for each Unique Cluster)

# %%
columns = ['cluster_id','mst_length_m', 'compounds_qty']
df = pd.DataFrame(columns=columns)

G1 = nx.Graph()

# v = range(1,18) + range(19,21) + range(38,39) + range(41,52)

for i in v:
    #print i##len(files))
    mst_i = connected_graph_mst(households[households['VILLAGE_1'] == i][['household-_gps_longitude','household-_gps_latitude']].values)
    mst_edges = mst_i.edges()
    mst_length = sum([np.ravel((coords_vec[u], coords_vec[v])) for (u, v) in mst_edges])
    compounds_qty = len(mst_edges)
    
    summary = pd.Series({'cluster_id':i, 
                         'mst_length_m':mst_length, 
                         'compounds_qty':compounds_qty})
        
    df.loc[i] = summary
    
    G2 = mst_i
    G1=nx.disjoint_union(G1, G2)


file_name = '/Users/carbz/Dropbox/Myanmar-ADB/10-draft_report/data/household_summary.csv'
df.to_csv(file_name, index = False)
print df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d40d5df8110c> in <module>()
#       6 # v = range(1,18) + range(19,21) + range(38,39) + range(41,52)
#       7
# ----> 8 for i in v:
#       9     #print i##len(files))
#      10     mst_i = connected_graph_mst(households[households['VILLAGE_1'] == i][['household/_gps_longitude','household/_gps_latitude']].values)
#
# TypeError: 'numpy.int64' object is not iterable

# %%
mst_i

# %%
#plot em all
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
nx.draw(G1, nx.get_node_attributes(G1, 'coords'), node_size=40, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-e5ffed90adc5> in <module>()
#       1 #plot em all
# ----> 2 fig = plt.figure(figsize=(10,10))
#       3 ax = fig.add_subplot(111)
#       4 nx.draw(G1, nx.get_node_attributes(G1, 'coords'), node_size=40, ax=ax)
#
# NameError: name 'plt' is not defined

# %%
#plot em all
# %pylab inline

mmr_nodes = connected_graph_mst(coords_vec)

# %%
#G = nx.DiGraph()

# %%
type(connected_graph_mst)
DG = nx.DiGraph()
#DG.add_weighted_edges_from()

# %%
mmr_nodes = mst_i.to_directed

# %% [markdown]
# #### 2.1 Output the gosh darn Shapefile version

# %%
mmr_nodes.edges(data=True)
nx.write_()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-371fe9b7c703> in <module>()
#       1 mmr_nodes.edges(data=True)
# ----> 2 nx.write_()
#
# AttributeError: 'module' object has no attribute 'write_'

# %%
out_shp = '/Users/carbz/Dropbox/Myanmar-ADB/10-draft_report/data/MST'
        
# # Write the shapefiles to path

mmr_nodes = G1.to_directed()
#kano_nodes = mst_i
#kano_nodes = nx.convert_node_labels_to_integers(G1)
mmr_nodes = nx.convert_node_labels_to_integers(mmr_nodes)
mmr_nodes = mmr_nodes.to_directed()
coords = nx.get_node_attributes(mmr_nodes, 'coords')
    
def make_node_wkt(n):
    return 'POINT ({x}, {y})'.format(x = coords[n][0], y=coords[n][1])
    
    
def make_edge_wkt(edge):
    fnode = coords[edge[0]]
    tnode = coords[edge[1]]
    linestring = 'LINESTRING ({x1} {y1}, {x2} {y2})'.format(x1=fnode[0], 
                                                           y1=fnode[1],
                                                           x2=tnode[0],
                                                           y2=tnode[1])
    return linestring

nx.set_node_attributes(mmr_nodes, 'Wkt', {n: make_node_wkt(n) for n in mmr_nodes.nodes()})
nx.set_edge_attributes(mmr_nodes, 'Wkt', {edge: make_edge_wkt(edge) for edge in mmr_nodes.edges()})

nx.write_shp(mmr_nodes, out_shp)

# %%
import ogr
outdir = out_shp

# %%
# Function manually outputting shapefile

__author__ = 'Brandon Ogle'

def write_edges(G, outdir):
    
    drv = ogr.GetDriverByName("ESRI Shapefile")
    shpdir = drv.CreateDataSource(outdir)
    
    

    edges = shpdir.CreateLayer("edges", None, ogr.wkbLineString)
    for (u, v, d) in G.edges(data=True):
        geoms = ogr.CreateGeometryFromWkt(d['Wkt'])
        
        feature = ogr.Feature(edges.GetLayerDefn())
        feature.SetGeometry(geoms)
        edges.CreateFeature(feature)
        feature.Destroy()
        
write_edges(kano_nodes, out_shp)

# %%
a = connected_graph_mst.edge[0]
b = connected_graph_mst.edge[1]
print coords_vec[a.keys()]
print coords_vec[b.keys()]


np.ravel(coords_vec[a.keys()]),np.ravel(coords_vec[b.keys()])
# get_hav_distance(coords_vec[a.keys()],coords_vec[b.keys()])
# Out:
# [[  8.61185034  10.74513365]]
# [[  9.167963    11.58851609]]
# (array([  8.61185034,  10.74513365]), array([  9.167963  ,  11.58851609]))

# %%
print np.ravel(mst_edges)
# Out:
# [  0 315   1 ..., 727 702 709]

# %%
node_df['Cluster']
# Out:
# 0     (8.61204367743, 10.7447537582)
# 1     (9.16942995766, 11.5871169191)
# 2     (8.54554244424, 12.2549680668)
# 3      (8.86426284283, 11.856832352)
# 4     (8.54724619757, 12.2522339026)
# 5     (8.85844884996, 11.8714048521)
# 6      (8.3921220849, 12.3228441568)
# 7     (8.86003853003, 11.8758345466)
# 8      (8.5603036881, 12.2567956332)
# 9      (8.3866346834, 12.3286597112)
# 10    (8.75135792872, 12.2922021494)
# 11    (8.54664701826, 12.2534406043)
# 12    (8.73212365295, 12.2935853374)
# 13    (8.54574043392, 12.2546167512)
# 14    (8.61262367864, 10.7454773539)
# ...
# 727    (9.17107512353, 11.5944752437)
# 728    (8.85899046168, 11.8701357689)
# 729     (9.1773941492, 11.5889990777)
# 730    (8.60922758236, 11.7211392485)
# 731     (8.61308399706, 10.746191903)
# 732    (9.17713404226, 11.5957897205)
# 733    (8.86024952382, 11.8748442948)
# 734    (8.85741207963, 11.8593151569)
# 735    (8.56061575631, 12.2592488146)
# 736    (9.17008039675, 11.5974724892)
# 737    (8.38167768033, 11.6652717939)
# 738    (8.61457542874, 10.7467707769)
# 739    (8.61343383906, 10.7440844306)
# 740    (8.60887939977, 11.7190937074)
# 741    (8.75428151844, 12.2885470521)
# Name: Cluster, Length: 742, dtype: object
