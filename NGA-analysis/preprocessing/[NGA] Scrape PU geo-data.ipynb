# %%
from lxml import etree

# %%
from bs4 import BeautifulSoup
import urllib2


def GetLatLong_NigeriaDecides(url_polling_unit):
    """
    Extract lat/long of interest for a given url
    INPUT: url of polling unit per NigeriaDecides.org site
    OUTPUT: single string of lat/long coordinates listed in the given url 
    ******************Example Useage************************************
     
    > url_nigeria_decides = ('https://nigeriadecide.org/polling_unit_locator.php' +
                           '?State=Cross+river' +
                           '&lga=Biase&ward=Erei+south' +
                           '&pu=09%2F06%2F08%2F007')
    >latlongs= GetLatLong_NigeriaDecides(url_nigeria_decides)
    > print(latlongs)
    >> LatLng(5.699844676,7.967985235)
    """
    page = get_page(url_polling_unit)
    nigeria_soup = BeautifulSoup(page.read())
    latlong_tag = nigeria_soup.head
    latlong_regex = 'LatLng.{25}'
    raw_text = latlong_tag.get_text()

    #print(len(latlong_tag.contents))

    #script_chunk = latlong_tag.contents[33:]
    
    coordinates = re.search(latlong_regex, raw_text)
    return(coordinates.group())




import backoff
import requests
@backoff.on_exception(backoff.expo,
                      requests.exceptions.RequestException,
                      max_tries=8)
def get_page(url):
    page = urllib2.urlopen(url_nigeria_decides)
    return(page)


#url="http://www.utexas.edu/world/univ/alpha/"
#url_nigeria_decides = "https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=16%2F18%2F01%2F007.html"
#url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=23%2F18%2F01%2F007'
#url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?pu=22%2F09%2F10%2F006'
#url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?state=Cross+river&lga=Biase&ward=Erei+south&pu=09%2F06%2F08%2F007'

#page = urllib2.urlopen(url_nigeria_decides)

# %%
GetLatLong_NigeriaDecides(url_nigeria_decides)
# Out:
# u'LatLng(6.482555374,6.710781015)'

# %%
page = urllib2.urlopen(url_nigeria_decides)
#page = requests.get(url_nigeria_decides)
soup = BeautifulSoup(page.read())

latlong_tag = soup.head
latlong_regex = 'LatLng.{25}'
raw_text = latlong_tag.get_text()

#print(len(latlong_tag.contents))

#script_chunk = latlong_tag.contents[33:]

coordinates = re.search(latlong_regex, raw_text)

#latlong_regex = 'LatLng.{25}'
#raw_text = latlong_tag.get_text()

#print(soup.get_text())

# page = BeautifulSoup(requested)
# #print(nigeria_soup.get_text())
#print(open(requested).read())
# nigeria_soup = BeautifulSoup(page.read())
# print(nigeria_soup.prettify)

# %%
print(soup.prettify)
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Find the nearest Polling unit to vote in 2015 Nigeria General elections. All Polling units included and Mapped @nigeriadecide" name="description"/>
# <meta content="CloudWare Technologies" name="author"/>
# <link href="assets/img/favicon.png" rel="shortcut icon"/>
# <title>Nigeria Decide 2015 - Nigeria 2015 Elections information | Polling Unit Locator</title>
# <!-- Bootstrap core CSS -->
# <link href="assets/css/bootstrap.css" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="assets/css/main.css" rel="stylesheet"/>
# <!-- Fonts from Google Fonts -->
# <link href="http://fonts.googleapis.com/css?family=Lato:300,400,900" rel="stylesheet" type="text/css"/>
# ...

# %%
type(requested)
#page2 = urllib2.urlopen(url_nigeria_decides)
#print(page2.text)
# Out:
# requests.models.Response

# %%
type(page2)
# Out:
# instance

# %%
url_nigeria_decides = "https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=16%2F18%2F01%2F007.html"

# %%
from bs4 import BeautifulSoup
#nigeria_soup = BeautifulSoup(niger_webpage)
#nigeria_soup = BeautifulSoup(open("https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=16%2F18%2F01%2F007"))
nigeria_soup = BeautifulSoup(state_page)
#print(nigeria_soup.get_text())
print(nigeria_soup.prettify)
# Out:
# <bound method BeautifulSoup.prettify of <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Find the nearest Polling unit to vote in 2015 Nigeria General elections. All Polling units included and Mapped @nigeriadecide" name="description"/>
# <meta content="CloudWare Technologies" name="author"/>
# <link href="assets/img/favicon.png" rel="shortcut icon"/>
# <title>Nigeria Decide 2015 - Nigeria 2015 Elections information | Polling Unit Locator</title>
# <!-- Bootstrap core CSS -->
# <link href="assets/css/bootstrap.css" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="assets/css/main.css" rel="stylesheet"/>
# <!-- Fonts from Google Fonts -->
# <link href="http://fonts.googleapis.com/css?family=Lato:300,400,900" rel="stylesheet" type="text/css"/>
# ...

# %%
import pandas as pd

nigeria_soup.contents
#len(nigeria_soup.contents)

body_tag = nigeria_soup.body
#print(type(body_tag))

####1.0 States########
state_url = 'https://nigeriadecide.org/polling_unit_locator.php'
state_page = get_page(url_nigeria_decides)
state_soup = BeautifulSoup(state_page.read())
body_tag_states = state_soup.body
container_states_lgas = body_tag_states.contents[5]
container_states_lgas = container_states_lgas.contents[3]


container_states = container_states_lgas.contents[5]
states = container_states.contents[1]

#print states
state_list = []

for child in states.contents[1:]:
    #print child.string
    state = child.string
    state_list.append(state)
    #print n
print state_list

#print(states)
# ######2.0 LGAs ####################
# container_lgas = container_states_lgas.contents[5]
# lgas = container_states.contents[3]

# lga_list = []

# for child in lgas.contents[2:]:
#     #print child.get_text()
#     lga = child.get_text()
#     n= n +1
#     lga_list.append(lga)
#     #print n
# print lga_list

# ##### 3.0 Wards #######################
# container_wards = container_states_lgas.contents[5]
# wards = container_wards.contents[5]
# #wards = wards.contents
# ward_regex = 'value='
# #ward_codes = re.findall(ward_regex, wards)
# #wards = wards.get_text()
# #print((wards.contents[1:]))

# #print(lgas)
# #print(wards)

# wards = []


# ######4.0 PU Units ####################
# #lga_code_regex = 
# #lga = container_states_lgas[2]
# pu_buttons = body_tag.contents[7]
# #print(len(pu_buttons))
# #print(pu_buttons)
# #print(pu_buttons.get_text())

# pu_code_regex = '(?<=PU:.).{13}'

# pu_codes = re.findall(pu_code_regex, pu_buttons.get_text())
# print(pu_codes[1:5])
# print(len(container_states_lgas.get_text()))
# #print(pu_buttons.get_text())
# Out:
# [u'Select a state\n\t', u'\n', u'Anambra\n\t', u'Abia\n\t', u'Adamawa\n\t', u'Akwa ibom\n\t', u'Anambra\n\t', u'Bauchi\n\t', u'Bayelsa\n\t', u'Benue\n\t', u'Borno\n\t', u'Cross river\n\t', u'Delta\n\t', u'Ebonyi\n\t', u'Edo\n\t', u'Ekiti\n\t', u'Enugu\n\t', u'Fct\n\t', u'Gombe\n\t', u'Imo\n\t', u'Jigawa\n\t', u'Kaduna\n\t', u'Kano\n\t', u'Katsina\n\t', u'Kebbi\n\t', u'Kogi\n\t', u'Kwara\n\t', u'Lagos\n\t', u'Nasarawa\n\t', u'Niger\n\t', u'Ogun\n\t', u'Ondo\n\t', u'Osun\n\t', u'Oyo\n\t', u'Plateau\n\t', u'Rivers\n\t', u'Sokoto\n\t', u'Taraba\n\t', u'Yobe\n\t', u'Zamfara\n\t', u'\n']

# %%
state_page = get_page(url_nigeria_decides)

# %%
state_page
# Out:
# <addinfourl at 4425498568 whose fp = <socket._fileobject object at 0x107c6db50>>

# %%
try:
  from lxml import etree
  print("running with lxml.etree")
except ImportError:
  try:
    # Python 2.5
    import xml.etree.cElementTree as etree
    print("running with cElementTree on Python 2.5+")
  except ImportError:
    try:
      # Python 2.5
      import xml.etree.ElementTree as etree
      print("running with ElementTree on Python 2.5+")
    except ImportError:
      try:
        # normal cElementTree install
        import cElementTree as etree
        print("running with cElementTree")
      except ImportError:
        try:
          # normal ElementTree install
          import elementtree.ElementTree as etree
          print("running with ElementTree")
        except ImportError:
          print("Failed to import ElementTree from any known place")
# Out:
# running with lxml.etree

# %%
root = etree.Element("root")
print(root.tag)
root.append( etree.Element("child1") )


child2 = etree.SubElement(root, "child2")
child3 = etree.SubElement(root, "child3")

print(etree.tostring(root, pretty_print=True))
# Out:
# root
# <root>
#   <child1/>
#   <child2/>
#   <child3/>
# </root>

# %%
print(html.xpath("string()")) # lxml.etree only!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-36bdfefc36bc> in <module>()
# ----> 1 print(html.xpath("string()")) # lxml.etree only!
#
# NameError: name 'html' is not defined

# %%
#Extract lat/long of interest for a given url
#INPUT: url of polling unit per NigeriaDecides.org site
#OUTPUT: single string of lat/long coordinates listed in the given url 
#******************Example Useage************************************
#  
# > url_nigeria_decides = ('https://nigeriadecide.org/polling_unit_locator.php' +
#                        '?State=Cross+river' +
#                        '&lga=Biase&ward=Erei+south' +
#                        '&pu=09%2F06%2F08%2F007')
# >latlongs= GetLatLong_NigeriaDecides(url_nigeria_decides)
# > print(latlongs)
# >> LatLng(5.699844676,7.967985235)

from bs4 import BeautifulSoup
def GetLatLong_NigeriaDecides(url_polling_unit):
    
    page = urllib2.urlopen(url_polling_unit)
    nigeria_soup = BeautifulSoup(page.read())
    latlong_tag = nigeria_soup.head
    latlong_regex = 'LatLng.{25}'
    raw_text = latlong_tag.get_text()

    #print(len(latlong_tag.contents))

    #script_chunk = latlong_tag.contents[33:]
    
    coordinates = re.search(latlong_regex, raw_text)
    return(coordinates.group())

# %%
url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?state=Anambra&lga=Anambra+west&ward=Nzam&pu=04%2F04%2F03%2F013'
page = urllib2.urlopen(url_nigeria_decides)

# %%
nigeria_soup = BeautifulSoup(page.read())
#print(nigeria_soup.prettify())
latlong_tag = nigeria_soup.head
raw_text = latlong_tag.get_text()
print(raw_text)
# Out:
# Nigeria Decide 2015 - Nigeria 2015 Elections information | Polling Unit Locator
#
#
#
#
#
#
#
#
#
#
# // This example displays a marker at the center of Australia.
# // When the user clicks the marker, an info window opens.
#
# function initialize() {
#   var myLatlng = new google.maps.LatLng(6.482555374,6.710781015);
#   var mapOptions = {
#     zoom: 16,
#     center: myLatlng
#   };
#
#   var map = new google.maps.Map(document.getElementById('map-canvas'), mapOptions);
#
#   var contentString = '<div id="content">'+
#       '<div id="siteNotice">'+
#       '</div>'+
#       '<h1 id="firstHeading" class="firstHeading">04/04/03/013</h1>'+
#       '<div id="bodyContent">'+
#       '<p><b>PU:04/04/03/013</b>, Is situated in Nzam Ward of'+
# 	  ' <i>Anambra west</i> Local Govenment Area in , ' +
#       '<b>Anambra</b> State,' +
#       'to enable you locate this Polling unit, <b>Note this</b>:The settlement is located near titus offors family compound,agbaja village'+
# ...

# %%
url_nigeria_decides = ('https://nigeriadecide.org/polling_unit_locator.php' +
                       '?State=Cross+river' +
                       '&lga=Biase&ward=Erei+south' +
                       '&pu=09%2F06%2F08%2F007')

#latlongs= GetLatLong_NigeriaDecides(url_nigeria_decides)
#print(latlongs)
print(url_nigeria_decides)
# Out:
# https://nigeriadecide.org/polling_unit_locator.php?State=Cross+river&lga=Biase&ward=Erei+south&pu=09%2F06%2F08%2F007

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

html_doc
# Out:
# '\n<html><head><title>The Dormouse\'s story</title></head>\n<body>\n<p class="title"><b>The Dormouse\'s story</b></p>\n\n<p class="story">Once upon a time there were three little sisters; and their names were\n<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,\n<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and\n<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;\nand they lived at the bottom of a well.</p>\n\n<p class="story">...</p>\n'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc)

for link in soup.find_all('a'):
    print(link.get('href'))
#print(soup.prettify())
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
soup = BeautifulSoup('<b class="boldest">Extremely bold</b>')
tag = soup.b
type(tag)
# Out:
# bs4.element.Tag

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>

<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc)

# %%
head_tag = soup.head
head_tag
head_tag.contents
len(soup.contents)

title_tag = head_tag.contents[0]
title_tag


#for child in title_tag.children:
 #   print(child)
    

#soup.find_all('b')
# Out:
# <title>The Dormouse's story</title>

# %%
import re
from bs4 import BeautifulSoup
import urllib2


url="http://www.utexas.edu/world/univ/alpha/"
#url_nigeria_decides = "https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=16%2F18%2F01%2F007.html"
#url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=23%2F18%2F01%2F007'
#url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?pu=22%2F09%2F10%2F006'
url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?state=Cross+river&lga=Biase&ward=Erei+south&pu=09%2F06%2F08%2F007'

page = urllib2.urlopen(url_nigeria_decides)
nigeria_voter = BeautifulSoup(page.read())

#print(nigeria_voter.prettify())

# %%
#print(page.read())


url="http://www.utexas.edu/world/univ/alpha/"
#page=urllib2.urlopen(url)
#soup = BeautifulSoup(page.read())

#print(soup.prettify())
#print(nigeria_voter.prettify())

# %%
import re
from bs4 import BeautifulSoup
import urllib2


#url_nigeria_decides = "https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=16%2F18%2F01%2F007.html"
#url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=23%2F18%2F01%2F007'
#url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?pu=22%2F09%2F10%2F006'
#nigeria_soup = BeautifulSoup(niger_webpage)
#nigeria_soup = BeautifulSoup(open())
url_nigeria_decides = 'https://nigeriadecide.org/polling_unit_locator.php?state=Cross+river&lga=Biase&ward=Erei+south&pu=09%2F06%2F08%2F007'



def GetLatLong_NigeriaDecides(url_polling_unit):
    
    page = urllib2.urlopen(url_polling_unit)
    nigeria_soup = BeautifulSoup(page.read())
    latlong_tag = nigeria_soup.head
    latlong_regex = 'LatLng.{25}'
    raw_text = latlong_tag.get_text()

    #print(len(latlong_tag.contents))

    #script_chunk = latlong_tag.contents[33:]
    
    coordinates = re.search(latlong_regex, raw_text)
    return(coordinates.group())

#latlong_tag.name
#type(latlong_tag)


#tag['class']
#tag.attrs
#latlong_tag.attrs # we dont have any latlong attributes
#print(latlong_tag.strings)


#print(latlong_tag.contents[33].name)

#import re

#latlong_tag.find_all('script')
# Out:
# 35
# LatLng(5.699844676,7.967985235)

# %%
from bs4 import BeautifulSoup
#nigeria_soup = BeautifulSoup(niger_webpage)
#nigeria_soup = BeautifulSoup(open("https://nigeriadecide.org/polling_unit_locator.php?state=Sokoto&lga=Tambuwal&ward=Romon+sarki&pu=16%2F18%2F01%2F007"))
nigeria_soup = BeautifulSoup(state_page)
print(nigeria_soup.get_text())

#print(nigeria_soup.prettify)
# Out:
# Nigeria Decide 2015 - Nigeria 2015 Elections information | Polling Unit Locator
#
#
#
#
#
#
#
#
#
#
# // This example displays a marker at the center of Australia.
# // When the user clicks the marker, an info window opens.
#
# function initialize() {
#   var myLatlng = new google.maps.LatLng(12.19183801,4.630907612);
#   var mapOptions = {
#     zoom: 16,
#     center: myLatlng
#   };
#
#   var map = new google.maps.Map(document.getElementById('map-canvas'), mapOptions);
#
#   var contentString = '<div id="content">'+
#       '<div id="siteNotice">'+
#       '</div>'+
#       '<h1 id="firstHeading" class="firstHeading">33/18/01/005</h1>'+
#       '<div id="bodyContent">'+
#       '<p><b>PU:33/18/01/005</b>, Is situated in Romon sarki Ward of'+
# 	  ' <i>Tambuwal</i> Local Govenment Area in , ' +
#       '<b>Sokoto</b> State,' +
#       'to enable you locate this Polling unit, <b>Note this</b>:The pu is located at the jumaa mosque of kanwuri village of kaya.'+
# ...

# %%
nigeria_soup.find(text='google.maps.LatLng')

# %%
soup.title
# <title>The Dormouse's story</title>

soup.title.name
# u'title'

soup.title.string
# u'The Dormouse's story'

soup.title.parent.name
# u'head'

soup.p
# <p class="title"><b>The Dormouse's story</b></p>

soup.p['class']
# u'title'

soup.a
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

soup.find_all('a')
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

soup.find(id="link3")
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
markup = "<b><!--Hey, buddy. Want to buy a used parser?--></b>"
soup = BeautifulSoup(markup)
comment = soup.b.string
type(comment)

from bs4 import CData
cdata = CData("A CDATA block")
comment.replace_with(cdata)

print(soup.b.prettify())
# Out:
# <b>
#  <![CDATA[A CDATA block]]>
# </b>

# %%
state_page ="""

<!DOCTYPE html>
<html lang="en">
  <head>
    <meta charset="utf-8">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <meta name="description" content="Find the nearest Polling unit to vote in 2015 Nigeria General elections. All Polling units included and Mapped @nigeriadecide">
    <meta name="author" content="CloudWare Technologies">
    <link rel="shortcut icon" href="assets/img/favicon.png">

    <title>Nigeria Decide 2015 - Nigeria 2015 Elections information | Polling Unit Locator</title>

    <!-- Bootstrap core CSS -->
    <link href="assets/css/bootstrap.css" rel="stylesheet">

    <!-- Custom styles for this template -->
    <link href="assets/css/main.css" rel="stylesheet">

    <!-- Fonts from Google Fonts -->
	<link href='http://fonts.googleapis.com/css?family=Lato:300,400,900' rel='stylesheet' type='text/css'>
    
    <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
    <!--[if lt IE 9]>
      <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
      <script src="https://oss.maxcdn.com/libs/respond.js/1.3.0/respond.min.js"></script>
    <![endif]-->
	
    <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyBcXUYCZoBgYH8RcLi_Ojfh4hcIbj_ixJE&sensor=false"></script>
    
		
	
	<script>
// This example displays a marker at the center of Australia.
// When the user clicks the marker, an info window opens.

function initialize() {
  var myLatlng = new google.maps.LatLng(12.19183801,4.630907612);
  var mapOptions = {
    zoom: 16,
    center: myLatlng
  };

  var map = new google.maps.Map(document.getElementById('map-canvas'), mapOptions);

  var contentString = '<div id="content">'+
      '<div id="siteNotice">'+
      '</div>'+
      '<h1 id="firstHeading" class="firstHeading">33/18/01/005</h1>'+
      '<div id="bodyContent">'+
      '<p><b>PU:33/18/01/005</b>, Is situated in Romon sarki Ward of'+
	  ' <i>Tambuwal</i> Local Govenment Area in , ' +
      '<b>Sokoto</b> State,' +
      'to enable you locate this Polling unit, <b>Note this</b>:The pu is located at the jumaa mosque of kanwuri village of kaya.'+
      'You can share/tweet this polling unit'+
      '<br/>@nigeriadecide.</p>'+
      '<p>Attribution: Nigeria Decide, <a href="http://nigeriadecide.org/">'+
      'Nigeria Decide</a> '+
      '(visit <a href="http://nigeriadecide.org/">Nigeria Decide</a> to be part of the this effort to make Nigeria democracy indeed democracy!).</p>'+
      '</div>'+
      '</div>';

  var infowindow = new google.maps.InfoWindow({
      content: contentString
  });

  var marker = new google.maps.Marker({
      position: myLatlng,
      map: map,
      title: 'PU:33/18/01/005'
  });
  google.maps.event.addListener(marker, 'click', function() {
    infowindow.open(map,marker);
  });
}

google.maps.event.addDomListener(window, 'load', initialize);

    </script>
	  </head>

  <body>
    <!-- Fixed navbar -->
    <div class="navbar navbar-default navbar-fixed-top">
      <div class="container">
        <div class="navbar-header">
          <button type="button" class="navbar-toggle" data-toggle="collapse" data-target=".navbar-collapse">
            <span class="icon-bar"></span>
            <span class="icon-bar"></span>
            <span class="icon-bar"></span>
          </button>
          <a class="navbar-brand" href="http://nigeriadecide.org"><b>Nigeria Decide</b></a>
        </div>
        <div class="navbar-collapse collapse">
          <ul class="nav navbar-nav navbar-right">
			<li><a href="2015_Nigeria_general_elections_voters_education.php" class="active">Voters Education</a></li>
			<li><a href="know_your_candidates.php">Know your Candidates</a></li>
			<li><a href="monitor_nigeria_2015_general_election.php">Monitor Election</a></li>
			<li><a href="polling_unit_locator.php">Polling Booth Locator</a></li>
			
			<li><a href="blog/" style="color:#f16304;"><b>Blog</b></a></li>
          </ul>
        </div><!--/.nav-collapse -->
      </div>
    </div>
	
	<div class="container">
	<!--/Content area -->
	<div class="row mt centered">
	
	<h1>Find the locations of polling units for 2015 Elections on Map</h1>
		<form action="" method="get">
	<select name="state" id="state" onchange="this.form.submit()" class="regis">
	<option value="">Select a state
	</option>
	
	<option value="Sokoto" selected="selected">Sokoto
	</option><option value="Abia">Abia
	</option><option value="Adamawa">Adamawa
	</option><option value="Akwa ibom">Akwa ibom
	</option><option value="Anambra">Anambra
	</option><option value="Bauchi">Bauchi
	</option><option value="Bayelsa">Bayelsa
	</option><option value="Benue">Benue
	</option><option value="Borno">Borno
	</option><option value="Cross river">Cross river
	</option><option value="Delta">Delta
	</option><option value="Ebonyi">Ebonyi
	</option><option value="Edo">Edo
	</option><option value="Ekiti">Ekiti
	</option><option value="Enugu">Enugu
	</option><option value="Fct">Fct
	</option><option value="Gombe">Gombe
	</option><option value="Imo">Imo
	</option><option value="Jigawa">Jigawa
	</option><option value="Kaduna">Kaduna
	</option><option value="Kano">Kano
	</option><option value="Katsina">Katsina
	</option><option value="Kebbi">Kebbi
	</option><option value="Kogi">Kogi
	</option><option value="Kwara">Kwara
	</option><option value="Lagos">Lagos
	</option><option value="Nasarawa">Nasarawa
	</option><option value="Niger">Niger
	</option><option value="Ogun">Ogun
	</option><option value="Ondo">Ondo
	</option><option value="Osun">Osun
	</option><option value="Oyo">Oyo
	</option><option value="Plateau">Plateau
	</option><option value="Rivers">Rivers
	</option><option value="Sokoto">Sokoto
	</option><option value="Taraba">Taraba
	</option><option value="Yobe">Yobe
	</option><option value="Zamfara">Zamfara
	</option>
	</select>
	
	<select name="lga" id="lga" onchange="this.form.submit()" class="regis"><option value="">Select a LGA
	</option><option value="Binji">Binji
	</option><option value="Bodinga">Bodinga
	</option><option value="Dange/shuni">Dange/shuni
	</option><option value="Gada">Gada
	</option><option value="Goronyo">Goronyo
	</option><option value="Gudu">Gudu
	</option><option value="Gwadabawa">Gwadabawa
	</option><option value="Illela">Illela
	</option><option value="Isa">Isa
	</option><option value="Kebbe">Kebbe
	</option><option value="Kware">Kware
	</option><option value="Rabah">Rabah
	</option><option value="S/birni">S/birni
	</option><option value="Shagari">Shagari
	</option><option value="Silame">Silame
	</option><option value="Sokoto north">Sokoto north
	</option><option value="Sokoto south">Sokoto south
	</option><option value="Tambuwal" selected="selected">Tambuwal
	</option><option value="Tambuwal">Tambuwal
	</option><option value="Tangaza">Tangaza
	</option><option value="Tureta">Tureta
	</option><option value="Wamakko">Wamakko
	</option><option value="Wurno">Wurno
	</option><option value="Yabo">Yabo
	</option></select>	
	
	<select name="ward" id="ward" onchange="this.form.submit()" class="regis"><option value="">Select a Ward
	</option><option value="Bagida/lukkingo">Bagida/lukkingo
	</option><option value="Bakaya/sabon birni">Bakaya/sabon birni
	</option><option value="Barkeji/nabaguda">Barkeji/nabaguda
	</option><option value="Bashire/maikada">Bashire/maikada
	</option><option value="Dogondaji/sala">Dogondaji/sala
	</option><option value="Faga/alasan">Faga/alasan
	</option><option value="Jabo/kagara">Jabo/kagara
	</option><option value="Romon sarki" selected="selected">Romon sarki
	</option><option value="Romon sarki">Romon sarki
	</option><option value="Saida/goshe">Saida/goshe
	</option><option value="Sanyinna">Sanyinna
	</option><option value="Tambuwal/shinfiri">Tambuwal/shinfiri
	</option></select>	
	<input type="submit" name="get_polling_unit" id="get_polling_unit" />
	
	
	<br/>
	
	
	
	</div>
	
	</div>
	<div class="container">
	
	<div style="width:30%; float:left; height:450px; overflow:auto;">
	Polling Units in selected Ward
	(12booths)<br/><b>PU: 33/18/01/009</b><br/>Bakin shago

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/009">View PU in Map</button><hr/>
	<b>PU: 33/18/01/004</b><br/>Barga dan fili

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/004">View PU in Map</button><hr/>
	<b>PU: 33/18/01/005</b><br/>Barga garkar liman

	<span style="color:green;"> Currently showing on Map</span><hr/>
	<b>PU: 33/18/01/002</b><br/>Kaya kanwuri i

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/002">View PU in Map</button><hr/>
	<b>PU: 33/18/01/003</b><br/>Kaya kanwuri ii

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/003">View PU in Map</button><hr/>
	<b>PU: 33/18/01/008</b><br/>Kaya pri. sch

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/008">View PU in Map</button><hr/>
	<b>PU: 33/18/01/006</b><br/>Kaya pri. sch.

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/006">View PU in Map</button><hr/>
	<b>PU: 33/18/01/007</b><br/>Kaya tshonon kawuri

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/007">View PU in Map</button><hr/>
	<b>PU: 33/18/01/012</b><br/>Ramon sarki pri. sch

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/012">View PU in Map</button><hr/>
	<b>PU: 33/18/01/011</b><br/>Ramon sarki titi

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/011">View PU in Map</button><hr/>
	<b>PU: 33/18/01/001</b><br/>Romon sarki - yar kasuwa

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/001">View PU in Map</button><hr/>
	<b>PU: 33/18/01/010</b><br/>Romon sarki kanwuri

	<button type="submit" class="btn btn-info" name="pu" id="pu" value="33/18/01/010">View PU in Map</button><hr/>
	</select>	
	</div>
	<div style="width:70%; float:left; height:450px;">
	Map location<br/>
	<b>PU:33/18/01/005 on the Map below</b>	
	<a href="https://twitter.com/share" class="twitter-share-button" data-via="nigeriadecide" data-related="nigeriadecide" data-hashtags="NigeriaDecide2015">Tweet</a>
<script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script>
<div class="fb-share-button" data-href="http://nigeriadecide.org" data-type="button"></div>
	<div id="map-canvas" style="min-width:600px;height:350px;"></div>
	 <div class="fb-comments" data-href="http://nigeriadecide.org" data-numposts="5" data-colorscheme="light"></div>	</div>
	</form>
	<br/>
		</div>
	
	
	
<div class="container">

	
<div>
<h4>Follow us on Social media for Update!</h4>
<div id="fb-root"></div>
<script>(function(d, s, id) {
  var js, fjs = d.getElementsByTagName(s)[0];
  if (d.getElementById(id)) return;
  js = d.createElement(s); js.id = id;
  js.src = "//connect.facebook.net/en_US/all.js#xfbml=1&appId=365318823599314";
  fjs.parentNode.insertBefore(js, fjs);
}(document, 'script', 'facebook-jssdk'));</script>

<a href="https://twitter.com/nigeriadecide" class="twitter-follow-button" data-show-count="false" data-size="large">Follow @nigeriadecide</a>
<script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script> &nbsp;&nbsp;&nbsp;
<!-- Place this tag where you want the widget to render. -->
<div class="g-follow" data-annotation="bubble" data-height="24" data-href="//plus.google.com/101675767132605557621" data-rel="publisher"></div>

<!-- Place this tag after the last widget tag. -->
<script type="text/javascript">
  (function() {
    var po = document.createElement('script'); po.type = 'text/javascript'; po.async = true;
    po.src = 'https://apis.google.com/js/platform.js';
    var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(po, s);
  })();
</script>
<div class="fb-like-box" data-href="https://www.facebook.com/nigeriadecide2015" data-colorscheme="light" data-show-faces="false" data-header="false" data-stream="false" data-show-border="true"></div>


</div> 
<!--Start of Zopim Live Chat Script-->
<script type="text/javascript">
window.$zopim||(function(d,s){var z=$zopim=function(c){z._.push(c)},$=z.s=
d.createElement(s),e=d.getElementsByTagName(s)[0];z.set=function(o){z.set.
_.push(o)};z._=[];z.set._=[];$.async=!0;$.setAttribute('charset','utf-8');
$.src='//cdn.zopim.com/?19qzy0Ap4I8hEc366w2kPFXo3tV91Ewy';z.t=+new Date;$.
type='text/javascript';e.parentNode.insertBefore($,e)})(document,'script');
</script>
<!--End of Zopim Live Chat Script--><br/>
	<a href="polling_unit_category.php">See the List of ALL 120,000 + elections polling Units in Nigeria</a><br/>
	</div>
	<div class="container">

		<hr>
		<br/>
		<p class="centered">Created by <a href="http://cloudware.ng">CloudWare Technologies</a> - Using CloudSMS <a href="http://cloudsms.com.ng">2Way SMS Platform</a> <br/>To support this project mail <a href="mailto:info@cloudware.ng">info@cloudware.ng</a></p>
	</div><!-- /container -->
	<div id="fb-root"></div>
<script>(function(d, s, id) {
  var js, fjs = d.getElementsByTagName(s)[0];
  if (d.getElementById(id)) return;
  js = d.createElement(s); js.id = id;
  js.src = "//connect.facebook.net/en_US/all.js#xfbml=1&appId=1393469734249764";
  fjs.parentNode.insertBefore(js, fjs);
}(document, 'script', 'facebook-jssdk'));</script>

    <!-- Bootstrap core JavaScript
    ================================================== -->
    <!-- Placed at the end of the document so the pages load faster -->
    <script src="https://code.jquery.com/jquery-1.10.2.min.js"></script>
    <script src="assets/js/bootstrap.min.js"></script>
	<script>
  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
  })(window,document,'script','//www.google-analytics.com/analytics.js','ga');

  ga('create', 'UA-46159519-1', 'nigeriadecide.org');
  ga('send', 'pageview');

</script>	
  </body>
</html>
"""
